# %% [markdown]
# <a href="https://colab.research.google.com/github/geoffreywambui76/geoffreys-project/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ohm's Law Calculator
voltage = float(input("Enter voltage (V): "))
resistance = float(input("Enter resistance (Ohms): "))

if resistance != 0:
    current = voltage / resistance
    print("Current (A):", current)
    power = voltage * current
    print("Power (W):", power)
else:
    print("Error: Resistance cannot be zero")
# Out:
# Enter voltage (V): 12
# Enter resistance (Ohms): 6
# Current (A): 2.0
# Power (W): 24.0
